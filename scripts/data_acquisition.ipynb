# %% [markdown]
# # Adquisición de Datos

# %% [markdown]
# En esta primera parte, se mostrará el script que invoca las distintas funcionalidades del código fuente del proyecto para realizar la adquisición de datos.
#
# En primer lugar, se traen todas las funciones y rutinas que serán utilizadas para este primer proceso de adquisición de datos

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.MLDS6_Assets.database import authenticateKaggle, downloadUnzipDataset , deleteFilesAndSubdirectories
from src.MLDS6_Assets.visualization import showImage , printTree

# %matplotlib inline

# %% [markdown]
# El primer paso, es realizar la respectiva conexión con la API de Kaggle para realizar la extracción inicial y desempaquetamiento de los datos.
#
# Esta primera parte consiste en autenticarse con la api de Kaggle usando el archivo `kaggle.json`, para posteriormente descargar el dataset [Chest X-Ray Images (Pneumonia)](https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia) que se encuentra libe y disponible en esta plataforma

# %%
url = 'https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia'
targetPath = '../data'
api = authenticateKaggle()
downloadUnzipDataset(api,url,targetPath)
# Out:
# Authenticated with Kaggle successfully.
# ...
#
# Dataset URL: https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia
# ...
# 100%|██████████| 2.29G/2.29G [10:33<00:00, 3.89MB/s]
# Dataset 'paultimothymooney/chest-xray-pneumonia' downloaded and unzipped to '../data'.

# %% [markdown]
# Podemos ahora visualizar las carpetas de contienen los datos adquiridos desde kaggle

# %%
deleteFilesAndSubdirectories('../data/')

# %%
printTree('../data/chest_xray/chest_xray')
# Out:
# 📁 chest_xray
#     📁 test
#         📁 NORMAL
#         📁 PNEUMONIA
#     📁 train
#         📁 NORMAL
#         📁 PNEUMONIA
#     📁 val
#         📁 NORMAL
#         📁 PNEUMONIA

# %% [markdown]
# También podemos visualizar algunas imagenes de cada conjunto de datos

# %%
title='Radiografía Normal'
path = '../data/chest_xray/train/NORMAL/IM-0115-0001.jpeg'
showImage(path = path, title=title)

# %%
title='Radiografía Neumonía Bacteriana'
path = '../data/chest_xray/train/PNEUMONIA/person1_bacteria_1.jpeg'
showImage(path = path, title=title)

# %%
title='Radiografía Neumonía Viral'
path = '../data/chest_xray/train/PNEUMONIA/person281_virus_578.jpeg'
showImage(path = path, title=title)
